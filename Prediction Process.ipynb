# %% [markdown]
# # **Cost of Treatment of Patient Prediction Based on Medical Cost Personal Datasets**
#
# **Part 1 - DEFINE**
#
# -----1.Define the problem----->
# Accurately Predict the insurance costs, based on medical cost personal dataset

# %%
import pandas.util.testing as tm
import numpy as np #  For linear algebra
import pandas as pd #  For data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import r2_score,mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Part 2 - DISCOVER**
#
# ----2.Load Dataset---->First mount the  Google Drive with Notebook then load dataset

# %%
from google.colab import drive
drive.mount('/drive',force_remount=True)
# Out:
# Mounted at /drive

# %%
# !cp /drive/'My Drive'/pmltesting.csv .
# !cp /drive/'My Drive'/pmltraining.csv .

# %% [markdown]
# # New Section

# %%
df= pd.read_csv('pmltraining.csv',low_memory=False)

# %% [markdown]
# > Indented block

# %%
df.shape
# Out:
# (19622, 160)

# %%
df
# Out:
#        Unnamed: 0 user_name  ...  magnet_forearm_z  classe
# 0               1  carlitos  ...             476.0       A
# 1               2  carlitos  ...             473.0       A
# 2               3  carlitos  ...             469.0       A
# 3               4  carlitos  ...             469.0       A
# 4               5  carlitos  ...             473.0       A
# ...           ...       ...  ...               ...     ...
# 19617       19618    adelmo  ...               6.0       E
# 19618       19619    adelmo  ...             -36.0       E
# 19619       19620    adelmo  ...             -70.0       E
# 19620       19621    adelmo  ...             -98.0       E
# 19621       19622    adelmo  ...            -110.0       E
#
# [19622 rows x 160 columns]

# %%
df.describe()
# Out:
#          Unnamed: 0  raw_timestamp_part_1  ...  magnet_forearm_y  magnet_forearm_z
# count  19622.000000          1.962200e+04  ...      19622.000000      19622.000000
# mean    9811.500000          1.322827e+09  ...        380.116445        393.613745
# std     5664.527827          2.049277e+05  ...        509.373742        369.268747
# min        1.000000          1.322490e+09  ...       -896.000000       -973.000000
# 25%     4906.250000          1.322673e+09  ...          2.000000        191.000000
# 50%     9811.500000          1.322833e+09  ...        591.000000        511.000000
# 75%    14716.750000          1.323084e+09  ...        737.000000        653.000000
# max    19622.000000          1.323095e+09  ...       1480.000000       1090.000000
#
# [8 rows x 123 columns]

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of        Unnamed: 0 user_name  ...  magnet_forearm_z  classe
# 0               1  carlitos  ...             476.0       A
# 1               2  carlitos  ...             473.0       A
# 2               3  carlitos  ...             469.0       A
# 3               4  carlitos  ...             469.0       A
# 4               5  carlitos  ...             473.0       A
# ...           ...       ...  ...               ...     ...
# 19617       19618    adelmo  ...               6.0       E
# 19618       19619    adelmo  ...             -36.0       E
# 19619       19620    adelmo  ...             -70.0       E
# 19620       19621    adelmo  ...             -98.0       E
# 19621       19622    adelmo  ...            -110.0       E
#
# [19622 rows x 160 columns]>

# %%
df.isnull().sum(axis=0)
# Out:
# Unnamed: 0              0
# user_name               0
# raw_timestamp_part_1    0
# raw_timestamp_part_2    0
# cvtd_timestamp          0
#                        ..
# accel_forearm_z         0
# magnet_forearm_x        0
# magnet_forearm_y        0
# magnet_forearm_z        0
# classe                  0
# Length: 160, dtype: int64

# %%
df_test= pd.read_csv('pmltesting.csv')

# %%
df_test.head(10)
# Out:
#    Unnamed: 0 user_name  ...  magnet_forearm_z  problem_id
# 0           1     pedro  ...               617           1
# 1           2    jeremy  ...               873           2
# 2           3    jeremy  ...               783           3
# 3           4    adelmo  ...               521           4
# 4           5    eurico  ...                91           5
# 5           6    jeremy  ...               884           6
# 6           7    jeremy  ...               585           7
# 7           8    jeremy  ...               -32           8
# 8           9  carlitos  ...               469           9
# 9          10   charles  ...               512          10
#
# [10 rows x 160 columns]

# %%
df_test.isnull().sum(axis=0)
# Out:
# Unnamed: 0              0
# user_name               0
# raw_timestamp_part_1    0
# raw_timestamp_part_2    0
# cvtd_timestamp          0
#                        ..
# accel_forearm_z         0
# magnet_forearm_x        0
# magnet_forearm_y        0
# magnet_forearm_z        0
# problem_id              0
# Length: 160, dtype: int64

# %%
df_test.shape
# Out:
# (20, 160)
